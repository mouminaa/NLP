# %%
import gzip
from yargy import Parser, rule, or_
from yargy.pipelines import morph_pipeline, caseless_pipeline
from yargy.interpretation import fact
from yargy.predicates import gram, dictionary, type as yargy_type, eq
import re
from typing import Optional
from dataclasses import dataclass

# --- Structure des données extraites
@dataclass
class Entry:
    name: str
    birth_date: Optional[str]
    birth_place: Optional[str]

# --- Règles de reconnaissance des entités
Person = fact(
    'Person',
    ['first', 'last']
)

NAME_RULE = rule(
    gram('Name').interpretation(Person.first),
    gram('Name').interpretation(Person.last)
)

DATE_RULE = rule(
    yargy_type('INT'),  # Jour
    or_(
        morph_pipeline(['января', 'февраля', 'марта', 'апреля', 'мая', 'июня',
                    'июля', 'августа', 'сентября', 'октября', 'ноября', 'декабря']),
        rule(yargy_type('INT'))  # Cas d'une date au format 15/05/1990
    ),
    yargy_type('INT')  # Année
).interpretation(fact('Date', ['day', 'month', 'year']))

DATE_SHORT_RULE = rule(
    yargy_type('INT'),
    eq('/'),
    yargy_type('INT'),
    eq('/'),
    yargy_type('INT')
).interpretation(fact('Date', ['day', 'month', 'year']))

BIRTHPLACE_RULE = rule(
    morph_pipeline([
        'Paris', 'Marseille', 'Lyon', 'Toulouse', 'Nice', 'France', 
        'Londres', 'Berlin', 'Moscou', 'New York', 'Tokyo', 'Bruxelles', 
        'Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 
        'Казань', 'Россия'

    ])
)

BIRTH_PHRASE_RULE = rule(
    dictionary({'родился', 'родилась'}),
    eq('в'),
    BIRTHPLACE_RULE.interpretation(fact('BirthPlace', ['location'])),
    dictionary({'в'}),
    or_(DATE_RULE, DATE_SHORT_RULE).interpretation(fact('Date', ['day', 'month', 'year']))
)

parser_name = Parser(NAME_RULE)
parser_date = Parser(DATE_RULE)
parser_short_date = Parser(DATE_SHORT_RULE)
parser_birthplace = Parser(BIRTHPLACE_RULE)
parser_birth_phrase = Parser(BIRTH_PHRASE_RULE)

# --- Fonction d'extraction des informations
def extract_information(text: str) -> Entry:
    name = None
    birth_date = None
    birth_place = None

    for match in parser_name.findall(text):
        name = ' '.join([_.value for _ in match.tokens])
        break  # On prend la première correspondance

    for match in parser_date.findall(text):
        day, month, year = [_.value for _ in match.tokens]
        birth_date = f'{day} {month} {year}'
        break

    for match in parser_short_date.findall(text):
        day, month, year = [_.value for _ in match.tokens]
        birth_date = f'{day}/{month}/{year}'
        break

    for match in parser_birthplace.findall(text):
        birth_place = match.tokens[0].value
        break

    for match in parser_birth_phrase.findall(text):
        tokens = [_.value for _ in match.tokens]
        birth_place = tokens[2]
        birth_date = '/'.join(tokens[4:7])
        break

    return Entry(name=name, birth_date=birth_date, birth_place=birth_place)

# --- Lecture du fichier GZ
def process_gz_file(file_path: str):
    with gzip.open(file_path, 'rt', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entry = extract_information(line)
                if entry.name or entry.birth_date or entry.birth_place:
                    print(entry)

# --- Lancer le traitement
process_gz_file('news.txt.gz')
# Out:
# Entry(name='Матс Сундин', birth_date='12 ноября 2012', birth_place=None)
# Entry(name='Владимир Филиппов', birth_date=None, birth_place='Казань')
# Entry(name='О том', birth_date=None, birth_place='России')
# Entry(name='Киитиро Тоёды', birth_date=None, birth_place=None)
# Entry(name='Бена Николсона', birth_date='24 февраля 2016', birth_place=None)
# Entry(name=None, birth_date='1 июня 2015', birth_place='России')
# Entry(name=None, birth_date='22 сентября 2011', birth_place=None)
# Entry(name=None, birth_date='12 октября 2016', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='Россия')
# Entry(name='Игорь Денисов', birth_date=None, birth_place='России')
# Entry(name='море Из', birth_date='7 июня 2016', birth_place='России')
# Entry(name='Ханс Ульрих', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='France')
# Entry(name=None, birth_date='19 июня 2014', birth_place='России')
# Entry(name='Энди Коулсон', birth_date=None, birth_place='New')
# Entry(name=None, birth_date='8 декабря 2015', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='Россией')
# Entry(name='Ян Цапник', birth_date='23 октября 2014', birth_place=None)
# Entry(name=None, birth_date='10 июля 2016', birth_place=None)
# Entry(name='Джон Кирби', birth_date='14 сентября 2016', birth_place='России')
# Entry(name='Джефф Монсон', birth_date=None, birth_place='России')
# Entry(name='О том', birth_date=None, birth_place='России')
# Entry(name=None, birth_date='9 сентября 2013', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='Москве')
# Entry(name='поля Венеры', birth_date='21 июня 2016', birth_place=None)
# Entry(name=None, birth_date='1 января 2014', birth_place='России')
# Entry(name='Андре Игуодалы', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='Фаррелл Уильямс', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='Москва')
# Entry(name='Ольга Скабеева', birth_date='8 июня 2016', birth_place='Россия')
# Entry(name=None, birth_date='1 октября 2013', birth_place='России')
# Entry(name=None, birth_date='1 января 1998', birth_place='France')
# Entry(name=None, birth_date='5 февраля 2015', birth_place='России')
# Entry(name='Дмитрий Циликин', birth_date=None, birth_place='Санкт')
# Entry(name='Вагит Алекперов', birth_date=None, birth_place='Москвы')
# Entry(name='Джастин Грэй', birth_date=None, birth_place=None)
# Entry(name='Джон Саймон', birth_date='2 февраля 1979', birth_place=None)
# Entry(name='Ванесса Паради', birth_date=None, birth_place=None)
# Entry(name='Анджелины Джоли', birth_date='1 января 2016', birth_place='России')
# Entry(name=None, birth_date='10 июля 2016', birth_place='России')
# Entry(name='Флорой Касадеи', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='Новосибирска')
# Entry(name='Джеки Смит', birth_date=None, birth_place=None)
# Entry(name='Рафаэля Надаля', birth_date=None, birth_place=None)
# Entry(name='Альгирдас Семета', birth_date=None, birth_place='France')
# Entry(name=None, birth_date='16 февраля 2016', birth_place=None)
# Entry(name=None, birth_date=None, birth_place='New')
# Entry(name='Петер Вестербака', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='Россия')
# Entry(name=None, birth_date='12 марта 2013', birth_place=None)
# Entry(name='Виктор Кирьянов', birth_date='4 декабря 2015', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='К тому', birth_date=None, birth_place=None)
# Entry(name=None, birth_date='9 июля 2015', birth_place='Санкт')
# Entry(name='Люк Айкинс', birth_date='16 августа 1960', birth_place=None)
# Entry(name='Пьера Огюста', birth_date=None, birth_place=None)
# Entry(name='Джек Джонсон', birth_date=None, birth_place='России')
# Entry(name='Сара Полсон', birth_date='7 октября 2015', birth_place=None)
# Entry(name=None, birth_date='27 мая 31', birth_place=None)
# Entry(name='Валерий Герасимов', birth_date=None, birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date='30 июня 2016', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date='14 июня 2016', birth_place='России')
# Entry(name='Максим Матвеев', birth_date='1 июля 2013', birth_place='России')
# Entry(name='Андрей Галиакберов', birth_date=None, birth_place='Москвы')
# Entry(name=None, birth_date='7 сентября 2013', birth_place=None)
# Entry(name='Рубена Дишдишяна', birth_date=None, birth_place='Москвы')
# Entry(name='Дэвида Уолтера', birth_date=None, birth_place='New')
# Entry(name='Криса Авеллона', birth_date=None, birth_place=None)
# Entry(name=None, birth_date='15 февраля 2013', birth_place='Россию')
# Entry(name=None, birth_date='28 декабря 2015', birth_place='России')
# Entry(name=None, birth_date='22 марта 2016', birth_place='Москву')
# Entry(name='Игорь Дыгало', birth_date=None, birth_place='России')
# Entry(name=None, birth_date=None, birth_place='Москва')
# Entry(name='Георгом Риманом', birth_date=None, birth_place=None)
# Entry(name='Джона Уоткинса', birth_date=None, birth_place=None)
# Entry(name='Жорже Жезуш', birth_date=None, birth_place=None)
# Entry(name='Кэрри Норрис', birth_date=None, birth_place=None)
# Entry(name=None, birth_date='21 июня 2015', birth_place=None)
# Entry(name='Рубеном Дишдишяном', birth_date='12 апреля 2011', birth_place=None)
# Entry(name='Мэтту Дэймону', birth_date=None, birth_place=None)
# Entry(name='О том', birth_date=None, birth_place='Россию')
# Entry(name='Стива Карелла', birth_date=None, birth_place=None)
# Entry(name='Владимиру Челомею', birth_date='25 августа 2016', birth_place=None)
# Entry(name=None, birth_date=None, birth_place='France')
# Entry(name='КИТ Финанс', birth_date='1 января 2016', birth_place='России')
# Entry(name=None, birth_date='30 января 2013', birth_place=None)
# Entry(name='Джон Ангер', birth_date='16 августа 2012', birth_place=None)
# Entry(name=None, birth_date='19 февраля 2009', birth_place=None)
# Entry(name='Терри Голду', birth_date=None, birth_place=None)
# Entry(name='Мэтт Смит', birth_date=None, birth_place=None)
# Entry(name=None, birth_date='2 января 2016', birth_place='России')
# Entry(name='Брайна Бикелла', birth_date=None, birth_place=None)
# Entry(name='Джона Мэтониса', birth_date='15 апреля 2016', birth_place=None)
# Entry(name='Василий Баранов', birth_date=None, birth_place='Казань')
# Entry(name='Ивана Таврина', birth_date=None, birth_place='России')
# Entry(name=None, birth_date=None, birth_place='Санкт')
# Entry(name=None, birth_date='23 февраля 2015', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='Антон Силуанов', birth_date=None, birth_place='России')
# Entry(name=None, birth_date='16 декабря 2014', birth_place='России')
# Entry(name='Дан Якир', birth_date=None, birth_place=None)
# Entry(name='Джеймса Ганна', birth_date='20 июля 2011', birth_place=None)
# Entry(name=None, birth_date='7 августа 2014', birth_place='Россию')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='Криштиану Роналду', birth_date=None, birth_place=None)
# Entry(name=None, birth_date='7 августа 2012', birth_place='России')
# Entry(name=None, birth_date='8 сентября 2014', birth_place=None)
# Entry(name='В августе', birth_date='14 ноября 2014', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='Россия')
# Entry(name='В марте', birth_date='25 февраля 2015', birth_place='России')
# Entry(name='Антон Силуанов', birth_date='11 ноября 2015', birth_place='Россия')
# Entry(name=None, birth_date='25 июля 2015', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='Томми Ли', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='Энтони Мандайна', birth_date=None, birth_place=None)
# Entry(name='Дэйв Кэллахам', birth_date='14 апреля 2015', birth_place=None)
# Entry(name=None, birth_date=None, birth_place='New')
# Entry(name='Марека Спанела', birth_date=None, birth_place=None)
# Entry(name='Федор Лукьянов', birth_date='15 июля 2016', birth_place='Москве')
# Entry(name='Энрико Исайя', birth_date=None, birth_place='России')
# Entry(name='В том', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='Россией')
# Entry(name='Марк Томас', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='Екатеринбурга')
# Entry(name=None, birth_date='13 октября 2005', birth_place=None)
# Entry(name=None, birth_date='8 февраля 2016', birth_place=None)
# Entry(name='Джош Сингер', birth_date=None, birth_place=None)
# Entry(name='Огюста Родена', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='Ванессой Паради', birth_date='23 мая 2016', birth_place=None)
# Entry(name='Анджелина Джоли', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='Россия')
# Entry(name='Константин Мурахтин', birth_date='25 ноября 2015', birth_place='России')
# Entry(name='Вагит Алекперов', birth_date=None, birth_place=None)
# Entry(name='Стивен Хилл', birth_date=None, birth_place='России')
# Entry(name='Стивен Тайлер', birth_date='11 октября 2011', birth_place=None)
# Entry(name='Валон Бериша', birth_date=None, birth_place='России')
# Entry(name='Бернарду Хопкинсу', birth_date=None, birth_place=None)
# Entry(name='Петр Лукьянов', birth_date=None, birth_place='Россия')
# Entry(name=None, birth_date=None, birth_place='Москве')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='Найт Шьямалана', birth_date='3 июня 2013', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='Москве')
# Entry(name='Лоренцо Лотто', birth_date='10 февраля 2013', birth_place='России')
# Entry(name='Дон Жуаном', birth_date='7 декабря 2011', birth_place='Москве')
# Entry(name=None, birth_date='25 июня 2009', birth_place=None)
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name='Динь Тьень', birth_date=None, birth_place=None)
# Entry(name='Сэм Мендес', birth_date='5 октября 2012', birth_place=None)
# Entry(name=None, birth_date='18 марта 2015', birth_place='России')
# Entry(name='Антон Силуанов', birth_date=None, birth_place='Россия')
# Entry(name='Орхан Памук', birth_date=None, birth_place='France')
# Entry(name='Эйдена Макгиди', birth_date=None, birth_place='России')
# Entry(name=None, birth_date='16 августа 1977', birth_place=None)
# Entry(name=None, birth_date='9 октября 2015', birth_place='России')
# Entry(name='Анджелиной Джоли', birth_date='1 января 2016', birth_place='России')
# Entry(name=None, birth_date='21 ноября 1998', birth_place='Санкт')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date='1 августа 2006', birth_place='Москва')
# Entry(name=None, birth_date='17 января 2013', birth_place='Россия')
# Entry(name='Анджелина Джоли', birth_date=None, birth_place=None)
# Entry(name=None, birth_date='2 декабря 2007', birth_place='Москве')
# Entry(name='Станислав Галимов', birth_date=None, birth_place='России')
# Entry(name=None, birth_date=None, birth_place='France')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date='17 сентября 2016', birth_place=None)
# Entry(name=None, birth_date='14 января 2015', birth_place='России')
# Entry(name='Дезмонд Майлз', birth_date=None, birth_place=None)
# Entry(name='Эшли Грэм', birth_date=None, birth_place=None)
# Entry(name=None, birth_date='25 ноября 2015', birth_place='России')
# Entry(name='Алексея Улюкаева', birth_date='9 сентября 2015', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date='7 марта 2014', birth_place=None)
# Entry(name='Аннетт Бенинг', birth_date=None, birth_place=None)
# Entry(name=None, birth_date=None, birth_place='России')
# Entry(name=None, birth_date='31 августа 2016', birth_place='России')
# Entry(name=None, birth_date=None, birth_place='Москве')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [1], line 112
#     109                     print(entry)
#     111 # --- Lancer le traitement
# --> 112 process_gz_file('news.txt.gz')
#
# Cell In [1], line 107, in process_gz_file(file_path)
#     105 for line in f:
#     106     if line.strip():
# --> 107         entry = extract_information(line)
#     108         if entry.name or entry.birth_date or entry.birth_place:
#     109             print(entry)
#
# Cell In [1], line 86, in extract_information(text)
#      83     break
#      85 for match in parser_short_date.findall(text):
# ---> 86     day, month, year = [_.value for _ in match.tokens]
#      87     birth_date = f'{day}/{month}/{year}'
#      88     break
#
# ValueError: too many values to unpack (expected 3)

# %%
import gzip
from yargy import Parser, rule, or_
from yargy.pipelines import morph_pipeline, caseless_pipeline
from yargy.interpretation import fact
from yargy.predicates import gram, dictionary, type as yargy_type, eq
import re
from typing import Optional
from dataclasses import dataclass

# --- Structure des données extraites
@dataclass
class Entry:
    name: str
    birth_date: Optional[str]
    birth_place: Optional[str]

# --- Règles de reconnaissance des entités
Person = fact(
    'Person',
    ['first', 'last']
)

NAME_RULE = rule(
    gram('Name').interpretation(Person.first),
    gram('Name').interpretation(Person.last)
)

DATE_RULE = rule(
    yargy_type('INT'),  # Jour
    or_(
        morph_pipeline(['января', 'февраля', 'марта', 'апреля', 'мая', 'июня',
                    'июля', 'августа', 'сентября', 'октября', 'ноября', 'декабря']),
        rule(yargy_type('INT'))  # Cas d'une date au format 15/05/1990
    ),
    yargy_type('INT')  # Année
).interpretation(fact('Date', ['day', 'month', 'year']))

DATE_SHORT_RULE = rule(
    yargy_type('INT'),
    eq('/'),
    yargy_type('INT'),
    eq('/'),
    yargy_type('INT')
).interpretation(fact('Date', ['day', 'month', 'year']))

BIRTHPLACE_RULE = rule(
    morph_pipeline([
        'Paris', 'Marseille', 'Lyon', 'Toulouse', 'Nice', 'France', 
        'Londres', 'Berlin', 'Moscou', 'New York', 'Tokyo', 'Bruxelles', 
        'Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 
        'Казань', 'Россия'

    ])
)

BIRTH_PHRASE_RULE = rule(
    dictionary({'родился', 'родилась'}),
    eq('в'),
    BIRTHPLACE_RULE.interpretation(fact('BirthPlace', ['location'])),
    dictionary({'в'}),
    or_(DATE_RULE, DATE_SHORT_RULE).interpretation(fact('Date', ['day', 'month', 'year']))
)

parser_name = Parser(NAME_RULE)
parser_date = Parser(DATE_RULE)
parser_short_date = Parser(DATE_SHORT_RULE)
parser_birthplace = Parser(BIRTHPLACE_RULE)
parser_birth_phrase = Parser(BIRTH_PHRASE_RULE)

# --- Fonction d'extraction des informations
def extract_information(text: str) -> Entry:
    name = "Non spécifié"
    birth_date = "Non spécifié"
    birth_place = "Non spécifié"

    # Extraction du nom
    for match in parser_name.findall(text):
        name = ' '.join([_.value for _ in match.tokens])
        break

    # Extraction de la date complète
    for match in parser_date.findall(text):
        tokens = [_.value for _ in match.tokens]
        if len(tokens) >= 3:  # Vérifie qu'il y a au moins 3 tokens
            day, month, year = tokens[:3]
            birth_date = f'{day} {month} {year}'
            break

    # Extraction de la date au format court
    for match in parser_short_date.findall(text):
        tokens = [_.value for _ in match.tokens]
        if len(tokens) >= 3:  # Vérifie qu'il y a au moins 3 tokens
            day, month, year = tokens[:3]
            birth_date = f'{day}/{month}/{year}'
            break

    # Extraction du lieu
    for match in parser_birthplace.findall(text):
        birth_place = match.tokens[0].value
        break

    # Extraction phrase complète (lieu + date)
    for match in parser_birth_phrase.findall(text):
        tokens = [_.value for _ in match.tokens]
        if len(tokens) >= 7:  # Vérifie qu'il y a au moins 7 tokens pour "родился в <lieu> в <date>"
            birth_place = tokens[2]
            birth_date = '/'.join(tokens[4:7])
            break

    return Entry(name=name, birth_date=birth_date, birth_place=birth_place)

# --- Lecture du fichier GZ
def process_gz_file(file_path: str):
    with gzip.open(file_path, 'rt', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                entry = extract_information(line)
                if entry.name or entry.birth_date or entry.birth_place:
                    print(entry)

# --- Lancer le traitement
process_gz_file('news.txt.gz')
# Out:
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Матс Сундин', birth_date='12 ноября 2012', birth_place='Non spécifié')
# Entry(name='Владимир Филиппов', birth_date='Non spécifié', birth_place='Казань')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='О том', birth_date='Non spécifié', birth_place='России')
# Entry(name='Киитиро Тоёды', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Бена Николсона', birth_date='24 февраля 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='1 июня 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='22 сентября 2011', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='12 октября 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Игорь Денисов', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='море Из', birth_date='7 июня 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ханс Ульрих', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='France')
# Entry(name='Non spécifié', birth_date='19 июня 2014', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Энди Коулсон', birth_date='Non spécifié', birth_place='New')
# Entry(name='Non spécifié', birth_date='8 декабря 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россией')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ян Цапник', birth_date='23 октября 2014', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='10 июля 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джон Кирби', birth_date='14 сентября 2016', birth_place='России')
# Entry(name='Джефф Монсон', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='О том', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='9 сентября 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='поля Венеры', birth_date='21 июня 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='1 января 2014', birth_place='России')
# Entry(name='Андре Игуодалы', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Фаррелл Уильямс', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москва')
# Entry(name='Ольга Скабеева', birth_date='8 июня 2016', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='1 октября 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='1 января 1998', birth_place='France')
# Entry(name='Non spécifié', birth_date='5 февраля 2015', birth_place='России')
# Entry(name='Дмитрий Циликин', birth_date='Non spécifié', birth_place='Санкт')
# Entry(name='Вагит Алекперов', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Джастин Грэй', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джон Саймон', birth_date='2 февраля 1979', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ванесса Паради', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Анджелины Джоли', birth_date='1 января 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='10 июля 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Флорой Касадеи', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Новосибирска')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джеки Смит', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Рафаэля Надаля', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Альгирдас Семета', birth_date='Non spécifié', birth_place='France')
# Entry(name='Non spécifié', birth_date='16 февраля 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='New')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Петер Вестербака', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='12 марта 2013', birth_place='Non spécifié')
# Entry(name='Виктор Кирьянов', birth_date='4 декабря 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='К тому', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='9 июля 2015', birth_place='Санкт')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Люк Айкинс', birth_date='16 августа 1960', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Пьера Огюста', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джек Джонсон', birth_date='Non spécifié', birth_place='России')
# Entry(name='Сара Полсон', birth_date='7 октября 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='27 мая 31', birth_place='Non spécifié')
# Entry(name='Валерий Герасимов', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='30 июня 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='14 июня 2016', birth_place='России')
# Entry(name='Максим Матвеев', birth_date='1 июля 2013', birth_place='России')
# Entry(name='Андрей Галиакберов', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='7 сентября 2013', birth_place='Non spécifié')
# Entry(name='Рубена Дишдишяна', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дэвида Уолтера', birth_date='Non spécifié', birth_place='New')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Криса Авеллона', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='15 февраля 2013', birth_place='Россию')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='28 декабря 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='22 марта 2016', birth_place='Москву')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Игорь Дыгало', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москва')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Георгом Риманом', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джона Уоткинса', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Жорже Жезуш', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Кэрри Норрис', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='21 июня 2015', birth_place='Non spécifié')
# Entry(name='Рубеном Дишдишяном', birth_date='12 апреля 2011', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Мэтту Дэймону', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='О том', birth_date='Non spécifié', birth_place='Россию')
# Entry(name='Стива Карелла', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Владимиру Челомею', birth_date='25 августа 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='France')
# Entry(name='КИТ Финанс', birth_date='1 января 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='30 января 2013', birth_place='Non spécifié')
# Entry(name='Джон Ангер', birth_date='16 августа 2012', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='19 февраля 2009', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Терри Голду', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Мэтт Смит', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='2 января 2016', birth_place='России')
# Entry(name='Брайна Бикелла', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джона Мэтониса', birth_date='15 апреля 2016', birth_place='Non spécifié')
# Entry(name='Василий Баранов', birth_date='Non spécifié', birth_place='Казань')
# Entry(name='Ивана Таврина', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Санкт')
# Entry(name='Non spécifié', birth_date='23 февраля 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Антон Силуанов', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='16 декабря 2014', birth_place='России')
# Entry(name='Дан Якир', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джеймса Ганна', birth_date='20 июля 2011', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='7 августа 2014', birth_place='Россию')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Криштиану Роналду', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='7 августа 2012', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='8 сентября 2014', birth_place='Non spécifié')
# Entry(name='В августе', birth_date='14 ноября 2014', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='В марте', birth_date='25 февраля 2015', birth_place='России')
# Entry(name='Антон Силуанов', birth_date='11 ноября 2015', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='25 июля 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Томми Ли', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Энтони Мандайна', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дэйв Кэллахам', birth_date='14 апреля 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='New')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Марека Спанела', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Федор Лукьянов', birth_date='15 июля 2016', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Энрико Исайя', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В том', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россией')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Марк Томас', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Екатеринбурга')
# Entry(name='Non spécifié', birth_date='13 октября 2005', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='8 февраля 2016', birth_place='Non spécifié')
# Entry(name='Джош Сингер', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Огюста Родена', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Ванессой Паради', birth_date='23 мая 2016', birth_place='Non spécifié')
# Entry(name='Анджелина Джоли', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Константин Мурахтин', birth_date='25 ноября 2015', birth_place='России')
# Entry(name='Вагит Алекперов', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Стивен Хилл', birth_date='Non spécifié', birth_place='России')
# Entry(name='Стивен Тайлер', birth_date='11 октября 2011', birth_place='Non spécifié')
# Entry(name='Валон Бериша', birth_date='Non spécifié', birth_place='России')
# Entry(name='Бернарду Хопкинсу', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Петр Лукьянов', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Найт Шьямалана', birth_date='3 июня 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Лоренцо Лотто', birth_date='10 февраля 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дон Жуаном', birth_date='7 декабря 2011', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='25 июня 2009', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Динь Тьень', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Сэм Мендес', birth_date='5 октября 2012', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='18 марта 2015', birth_place='России')
# Entry(name='Антон Силуанов', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Орхан Памук', birth_date='Non spécifié', birth_place='France')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Эйдена Макгиди', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='16 августа 1977', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='9 октября 2015', birth_place='России')
# Entry(name='Анджелиной Джоли', birth_date='1 января 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='21 ноября 1998', birth_place='Санкт')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='1 августа 2006', birth_place='Москва')
# Entry(name='Non spécifié', birth_date='17 января 2013', birth_place='Россия')
# Entry(name='Анджелина Джоли', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='2 декабря 2007', birth_place='Москве')
# Entry(name='Станислав Галимов', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='France')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='17 сентября 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='14 января 2015', birth_place='России')
# Entry(name='Дезмонд Майлз', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Эшли Грэм', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='25 ноября 2015', birth_place='России')
# Entry(name='Алексея Улюкаева', birth_date='9 сентября 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='7 марта 2014', birth_place='Non spécifié')
# Entry(name='Аннетт Бенинг', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='31 августа 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Сами Дирико', birth_date='8///15', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='15 мая 2016', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Франса Баннинга', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='С марта', birth_date='Non spécifié', birth_place='России')
# Entry(name='Ибрагим аль', birth_date='26 февраля 2016', birth_place='России')
# Entry(name='Владислав Масалов', birth_date='18 февраля 2015', birth_place='Non spécifié')
# Entry(name='Анастасия Боболаки', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ильхам Алиев', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='22 сентября 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='16 апреля 2015', birth_place='Non spécifié')
# Entry(name='Элен Смитэм', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джорджа Мартина', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='О том', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В том', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Роберт Зилджан', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Кристофер Нолан', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Каримой Эль', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Антон Силуанов', birth_date='18 марта 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Олег Бударгин', birth_date='1 августа 2012', birth_place='России')
# Entry(name='Эрика Джонсона', birth_date='Non spécifié', birth_place='France')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='29 ноября 2015', birth_place='Non spécifié')
# Entry(name='Юэль Киннаман', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Елена Наумчик', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Александр Петров', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дугласа Уильямса', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ларс Ульрих', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Майкла Дугласа', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Жозе Падилью', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Симона Байлз', birth_date='13 ноября 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Кубрат Пулев', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ричардом Гиром', birth_date='29 сентября 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Алан Брэд', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='из плей', birth_date='Non spécifié', birth_place='России')
# Entry(name='Ай Вэйвэй', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Мик Джаггер', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джейсон Рубин', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джанни Инфантино', birth_date='26 февраля 2016', birth_place='Non spécifié')
# Entry(name='Павел Хамидулин', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='22 июля 2016', birth_place='Non spécifié')
# Entry(name='Натали Пешала', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дэна Дэвида', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Анри Сальвадора', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='19 февраля 2014', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='23 августа 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='6 февраля 2013', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='14 августа 2013', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='9 августа 2011', birth_place='России')
# Entry(name='роман Евгения', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Анри Гильбо', birth_date='6 апреля 1917', birth_place='Россию')
# Entry(name='из амадин', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Леонида Гозмана', birth_date='21 октября 2008', birth_place='New')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='3 декабря 2010', birth_place='Non spécifié')
# Entry(name='Тим Фрэйлинг', birth_date='28 августа 2012', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Салават Юлаев', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='23 мая 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россию')
# Entry(name='Руслан Байсаров', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Джона Кэнэдэя', birth_date='Non spécifié', birth_place='New')
# Entry(name='Джин Сперлинг', birth_date='1 октября 2013', birth_place='Non spécifié')
# Entry(name='Майка Пондсмита', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='17 апреля 2014', birth_place='Non spécifié')
# Entry(name='Леонид Федун', birth_date='4 июля 2012', birth_place='России')
# Entry(name='Павел Кулижников', birth_date='10 марта 2016', birth_place='России')
# Entry(name='Кашан Кафур', birth_date='6 марта 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Евгения Альбац', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Юрий Иванов', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джонсом из', birth_date='25 февраля 2012', birth_place='Москве')
# Entry(name='Филиппин Александра', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джейсона Вурхиза', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Святослав Бэлза', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='2 мая 2015', birth_place='France')
# Entry(name='Джон Ранкин', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Гандольфини В', birth_date='20 июня 2013', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='31 октября 2014', birth_place='Россию')
# Entry(name='Алан Джардин', birth_date='27 апреля 2012', birth_place='Non spécifié')
# Entry(name='из Израиля', birth_date='3 октября 2015', birth_place='Россию')
# Entry(name='Non spécifié', birth_date='8 июля 2011', birth_place='России')
# Entry(name='Джон Карвер', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='4 февраля 1993', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='8 марта 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='12 марта 2015', birth_place='Non spécifié')
# Entry(name='Анатолий Сулейманов', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Вагит Алекперов', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='29 марта 2011', birth_place='France')
# Entry(name='Максим Топилин', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Вагит Алекперов', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В августе', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Кристин Лагард', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='12 июня 2014', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Альфонсо Куарона', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Майкл Шугар', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Владимир Максимов', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='1 августа 2013', birth_place='Non spécifié')
# Entry(name='Антон Астахов', birth_date='1 ноября 2012', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='1 января 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='9 декабря 2013', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Новосибирском')
# Entry(name='Ридли Скоттов', birth_date='31 марта 2012', birth_place='Non spécifié')
# Entry(name='Матильда Лоран', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В Израиле', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Сэйджу Уолловеру', birth_date='25 марта 2010', birth_place='Non spécifié')
# Entry(name='Мэри Джейн', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='6 октября 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='31 августа 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Даррен Иден', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В Скотланд', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Клаудио Маркизио', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='7 декабря 2014', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Том Хогарти', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Игорь Шестеркин', birth_date='Non spécifié', birth_place='России')
# Entry(name='В марте', birth_date='Non spécifié', birth_place='России')
# Entry(name='Трейси Эмин', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ольга Кимайо', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Лионель Месси', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='19 июля 2013', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Егор Бероев', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В августе', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Рамзан Кадыров', birth_date='6 октября 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Петер Эстерхази', birth_date='Non spécifié', birth_place='New')
# Entry(name='Non spécifié', birth_date='11 января 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='20 февраля 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='12 апреля 2013', birth_place='Non spécifié')
# Entry(name='Евгений Трефилов', birth_date='22 августа 2016', birth_place='России')
# Entry(name='Дэниел Крейг', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='17 ноября 2011', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Руперт Сандерс', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Эд Ширан', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='New')
# Entry(name='Криса Дюхона', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Адама Нимана', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москву')
# Entry(name='Алла Забровская', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джон Митани', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='18 мая 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='14 октября 2015', birth_place='Non spécifié')
# Entry(name='В Риме', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='25 июля 2014', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Анатолием Гуницким', birth_date='12 декабря 2015', birth_place='России')
# Entry(name='Стюарт Хилл', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Исаака Башевиса', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Стивен Келман', birth_date='Non spécifié', birth_place='France')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ян Темплар', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Хелена Бонэм', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джозеф Редмонд', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='23 октября 2012', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Ислам Каримов', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Джей Джей', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Ванессой Паради', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джеймс Долан', birth_date='17 мая 2013', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Мишель Монахэн', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Алин Смит', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Лионель Месси', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Альбертом Гором', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В августе', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Оскаром Писториусом', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='21 июля 2016', birth_place='России')
# Entry(name='Марка Миллара', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Терри Болеа', birth_date='30 октября 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дэниэл Мандил', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='New')
# Entry(name='Non spécifié', birth_date='6 апреля 2012', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Огтай Гумбат', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='ФСВТС Александра', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Пола Томаса', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Кристал Ли', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='15 февраля 2013', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Юлию Гёргес', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москва')
# Entry(name='Дмитрий Тулин', birth_date='26 августа 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='07 июня 2016', birth_place='России')
# Entry(name='Александр Агеев', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='8 июля 2015', birth_place='Москва')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Екатеринбурге')
# Entry(name='Чарли Ханнэм', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дмитрий Горин', birth_date='1 декабря 2015', birth_place='России')
# Entry(name='Джон Таварес', birth_date='22 ноября 2014', birth_place='Non spécifié')
# Entry(name='Джеймс Р', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='12 сентября 2010', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='1 августа 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='17 января 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Сергей Лавров', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Криштиану Роналду', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='14 сентября 2016', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Николасом Джорджем', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Стивен Фрай', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дженнифер Томас', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='22 июля 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='ПАСО Игоря', birth_date='21 августа 2013', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Андрей Назаров', birth_date='17 октября 2015', birth_place='Non spécifié')
# Entry(name='Владимир Константинов', birth_date='5 марта 2014', birth_place='России')
# Entry(name='Non spécifié', birth_date='17 декабря 2010', birth_place='России')
# Entry(name='Non spécifié', birth_date='11 марта 2011', birth_place='Non spécifié')
# Entry(name='Ринат Билялетдинов', birth_date='20 декабря 2014', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='15 сентября 2016', birth_place='России')
# Entry(name='Брайан Уэйн', birth_date='22 апреля 2014', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москва')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='из графена', birth_date='12 сентября 2014', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='5 августа 2011', birth_place='Non spécifié')
# Entry(name='Юкия Амано', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='КРЭТ Игорь', birth_date='25 сентября 2014', birth_place='России')
# Entry(name='Брэд Леланд', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# ...
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дании Ларса', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Анна Погорилая', birth_date='Non spécifié', birth_place='России')
# Entry(name='В августе', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='France')
# Entry(name='Non spécifié', birth_date='1 января 2016', birth_place='России')
# Entry(name='оливье В', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='свет тем', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Оскару Кардосу', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Стивена Патрика', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='24 июля 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='30 апреля 2015', birth_place='Россия')
# Entry(name='Аксель Шпрингер', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='03 октября 2016', birth_place='Non spécifié')
# Entry(name='Коринн Рэй', birth_date='15 июля 2016', birth_place='Nice')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москву')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='17 ноября 2014', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='13 июля 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='3 сентября 2014', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джош Голд', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='12 октября 2012', birth_place='Non spécifié')
# Entry(name='Диего Тарделли', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Дмитрий Еремеев', birth_date='17 мая 2015', birth_place='Non spécifié')
# Entry(name='Артем Тагиров', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='люк из', birth_date='21 апреля 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Юрий Исаев', birth_date='18 мая 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Жанной Булах', birth_date='8 июля 2013', birth_place='России')
# Entry(name='Антон Силуанов', birth_date='27 апреля 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='8 ноября 2011', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='29 января 1951', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Альберто Артиоли', birth_date='23 июля 2010', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='14 мая 2015', birth_place='России')
# Entry(name='Сергей Михалок', birth_date='Non spécifié', birth_place='России')
# Entry(name='Яннису Стурнарасу', birth_date='Non spécifié', birth_place='France')
# Entry(name='Уильяму Поули', birth_date='23 марта 2011', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='25 апреля 2016', birth_place='Non spécifié')
# Entry(name='Игорь Акинфеев', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Каролины Майкл', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Стюарт Даунинг', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='22 мая 2014', birth_place='Россия')
# Entry(name='Евгением Гинером', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джеймсом Бейкером', birth_date='1 июня 1990', birth_place='России')
# Entry(name='Алексей Венедиктов', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='2 февраля 2015', birth_place='России')
# Entry(name='Антон Силуанов', birth_date='20 февраля 2016', birth_place='России')
# Entry(name='Лилианне Лунгиной', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Руслан Бальбек', birth_date='7 июля 2016', birth_place='Non spécifié')
# Entry(name='Джеймс Сиринг', birth_date='27 февраля 2015', birth_place='Россия')
# Entry(name='Магнусом Карлсеном', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='20 июня 2012', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='France')
# Entry(name='Алексей Улюкаев', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='7 октября 2011', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='31 декабря 2012', birth_place='France')
# Entry(name='Кима Чельстрема', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='28 июля 2011', birth_place='Non spécifié')
# Entry(name='Майклом Амодтом', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='из Израиля', birth_date='10 февраля 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='О Павле', birth_date='19 июня 2012', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='11 марта 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россию')
# Entry(name='Non spécifié', birth_date='30 марта 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В августе', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='3 февраля 2016', birth_place='России')
# Entry(name='В марте', birth_date='26 января 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='2 апреля 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='5 августа 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москву')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россию')
# Entry(name='Non spécifié', birth_date='8 апреля 2016', birth_place='Москве')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='France')
# Entry(name='Non spécifié', birth_date='16 февраля 2016', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='18 января 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='10 сентября 2013', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Россию')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='New')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='28 ноября 2009', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='21 марта 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Клод Бартолон', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джоан Мари', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Сэма Рэйми', birth_date='6 марта 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Уэнди Кларк', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джон Дуглас', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Алексей Моисеев', birth_date='1 марта 2016', birth_place='России')
# Entry(name='Джоан Роулинг', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='В марте', birth_date='1 мая 2013', birth_place='Non spécifié')
# Entry(name='Борис Мазо', birth_date='15 марта 2016', birth_place='Москвы')
# Entry(name='В том', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Санкт')
# Entry(name='Андреа Париси', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Жером Шампань', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='24 августа 2015', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москвы')
# Entry(name='Юлия Савичева', birth_date='Non spécifié', birth_place='России')
# Entry(name='Дэнни Фрэйном', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Вальдемар Форналик', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='3 сентября 2016', birth_place='России')
# Entry(name='О том', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='15 января 2013', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Алексей Улюкаев', birth_date='17 января 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='26 ноября 2013', birth_place='Non spécifié')
# Entry(name='Роберт Дауни', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='20 мая 2015', birth_place='России')
# Entry(name='Non spécifié', birth_date='26 мая 2016', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='19 января 2015', birth_place='России')
# Entry(name='Артема Пацева', birth_date='1 января 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Алексея Емелина', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Леонид Федун', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Брэд Ричардс', birth_date='Non spécifié', birth_place='России')
# Entry(name='Дэн Грэм', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Альберто Мораиса', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джек Гилберт', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='25 декабря 2015', birth_place='России')
# Entry(name='Раджива Бисваса', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Танвира Махмуда', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Сержем Саргсяном', birth_date='16 января 2015', birth_place='России')
# Entry(name='Сергей Куприянов', birth_date='24 мая 2013', birth_place='России')
# Entry(name='Non spécifié', birth_date='16 июня 2015', birth_place='Россия')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Джо Данте', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='1 сентября 2015', birth_place='России')
# Entry(name='Максим Топилин', birth_date='3 апреля 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Москве')
# Entry(name='В том', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
# Entry(name='Константина Малофеева', birth_date='Non spécifié', birth_place='Россия')
# Entry(name='Дэн Бэрлетт', birth_date='Non spécifié', birth_place='New')
# Entry(name='Non spécifié', birth_date='18 апреля 2016', birth_place='России')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='Non spécifié')
# Entry(name='Non spécifié', birth_date='Non spécifié', birth_place='России')
